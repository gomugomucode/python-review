# %%
import torch
import numpy as np

# here creatimng the zero tensor of 4 row and 5 colum
zero_tensor = torch.zeros(4,5)  

# creating 1 tensor  having 1 in 4 row and 5 colum
one_tensor = torch.ones(4,5)


# creatinfg a randome numbner tensor between 0 and 1 
rand_tensor = torch.rand(4 , 6)

data = [1,2,3],[111,43,6]

x =  torch.tensor(data)


# print(zero_tensor)
# print(one_tensor)
# print(rand_tensor)
print(x)
# Out:
# tensor([[  1,   2,   3],
#         [111,  43,   6]])

# %%
# To print the dimension/shape of the tensor, use .size() or .shape
print(x.size())
print(x.shape)
# Out:
# torch.Size([2, 3])
# torch.Size([2, 3])
